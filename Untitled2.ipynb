# %% [markdown]
# <a href="https://colab.research.google.com/github/yerrapureddy/590_Spring_2024_Udaykumarreddy_yerrapureddy/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed May  1 07:36:35 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0              50W / 350W |    625MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # New section

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/yolov9

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (216/216), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 325 (delta 158), reused 155 (delta 155), pack-reused 109
# Receiving objects: 100% (325/325), 2.23 MiB | 26.61 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/yolov9/yolov9

# %%
# !pip install -q roboflow

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402444
# drwxr-xr-x  2 root root      4096 May  1 07:37 .
# drwxr-xr-x 16 root root      4096 May  1 07:37 ..
# -rw-r--r--  1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r--  1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r--  1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r--  1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %%
# %cd {HOME}/yolov9
# Out:
# /content/yolov9/yolov9

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="28iqHVpEfgX0GzhZWVVU")
project = rf.workspace("uday-uejhk").project("project1-agenr")
version = project.version(2)
dataset = version.download("yolov9")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.28)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.18)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.2)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.51.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in project1-2 to yolov9:: 100%|██████████| 7968/7968 [00:01<00:00, 4712.35it/s]
# Extracting Dataset Version Zip to project1-2 in yolov9:: 100%|██████████| 312/312 [00:00<00:00, 6673.72it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="28iqHVpEfgX0GzhZWVVU")
project = rf.workspace("bddsample2").project("rmsw_5k_night-riwja")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.28)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.2)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.51.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="28iqHVpEfgX0GzhZWVVU")
project = rf.workspace("uday-uejhk").project("city-scapes-eu0kh")
version = project.version(2)
dataset = version.download("yolov9")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.28)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.18)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.2)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.51.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in city-scapes-2 to yolov9:: 100%|██████████| 189100/189100 [00:12<00:00, 15437.41it/s]
# Extracting Dataset Version Zip to city-scapes-2 in yolov9:: 100%|██████████| 12314/12314 [00:01<00:00, 7980.28it/s]

# %%
# %cd {HOME}/yolov9

# !python train.py \
--batch 16 --epochs 10 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9/yolov9
# 2024-05-01 07:42:55.710181: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-01 07:42:55.710238: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-01 07:42:55.712105: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-01 07:42:56.726294: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=/content/yolov9/weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=/content/yolov9/yolov9/project1-2/data.yaml, hyp=hyp.scratch-high.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=11
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5499121  models.yolo.DDetect                     [11, [256, 512, 512]]
# gelan-c summary: 621 layers, 25445553 parameters, 25445537 gradients, 103.2 GFLOPs
#
# Transferred 931/937 items from /content/yolov9/weights/gelan-c.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# train: Scanning /content/yolov9/yolov9/project1-2/train/labels... 96 images, 0 backgrounds, 0 corrupt: 100% 96/96 [00:00<00:00, 3507.62it/s]
# train: New cache created: /content/yolov9/yolov9/project1-2/train/labels.cache
# val: Scanning /content/yolov9/yolov9/project1-2/valid/labels... 40 images, 0 backgrounds, 0 corrupt: 100% 40/40 [00:00<00:00, 1642.63it/s]
# val: New cache created: /content/yolov9/yolov9/project1-2/valid/labels.cache
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/exp
# Starting training for 10 epochs...
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         0/9      14.5G      1.654      4.746      1.212        560        640: 100% 6/6 [00:18<00:00,  3.07s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.06it/s]
#                    all         40        767     0.0365      0.241     0.0293     0.0202
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/9      14.5G      1.578      3.699      1.233        433        640: 100% 6/6 [00:02<00:00,  2.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.81it/s]
#                    all         40        767      0.863     0.0595     0.0796     0.0489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/9      14.5G      1.409      2.192      1.155        427        640: 100% 6/6 [00:02<00:00,  2.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  4.08it/s]
#                    all         40        767      0.744     0.0647      0.109     0.0672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/9      14.5G      1.351      1.673       1.11        457        640: 100% 6/6 [00:02<00:00,  2.97it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  4.04it/s]
#                    all         40        767      0.495      0.171      0.162     0.0902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/9      16.1G      1.315      1.452      1.098        807        640: 100% 6/6 [00:02<00:00,  2.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.78it/s]
#                    all         40        767      0.662      0.175      0.194      0.108
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/9      16.1G      1.339      1.352      1.122        701        640: 100% 6/6 [00:02<00:00,  2.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.96it/s]
#                    all         40        767      0.611      0.227      0.228      0.132
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         6/9      16.1G      1.262       1.18      1.047        699        640: 100% 6/6 [00:02<00:00,  2.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  4.05it/s]
#                    all         40        767      0.655      0.275      0.275      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         7/9      16.1G      1.292      1.168      1.094        394        640: 100% 6/6 [00:02<00:00,  2.91it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  4.10it/s]
#                    all         40        767      0.698      0.294      0.304      0.174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         8/9      16.1G      1.227      1.096      1.068        474        640: 100% 6/6 [00:02<00:00,  2.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  4.09it/s]
#                    all         40        767      0.718      0.299      0.319      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         9/9      16.1G      1.188      1.035      1.055        422        640: 100% 6/6 [00:02<00:00,  2.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  4.10it/s]
#                    all         40        767      0.758      0.293      0.323      0.188
#
# 10 epochs completed in 0.018 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, saved as runs/train/exp/weights/last_striped.pt, 51.5MB
# Optimizer stripped from runs/train/exp/weights/best.pt, saved as runs/train/exp/weights/best_striped.pt, 51.5MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# gelan-c summary: 467 layers, 25419441 parameters, 0 gradients, 102.5 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  3.04it/s]
#                    all         40        767       0.76      0.293      0.323      0.188
#                bicycle         40         10      0.442        0.5      0.365      0.101
#                    bus         40         13      0.866      0.462      0.596        0.5
#                    car         40        377      0.818      0.658      0.748      0.493
#             motorcycle         40          2          1          0          0          0
#          other vehicle         40          2          1          0     0.0169     0.0135
#             pedestrian         40         80      0.696      0.362       0.44      0.189
#                  rider         40          3          1          0          0          0
#          traffic light         40         96      0.599      0.365       0.38      0.175
#           traffic sign         40        158      0.555       0.31      0.374      0.167
#                  truck         40         26      0.625      0.269       0.31      0.239
# Results saved to runs/train/exp

# %%
# !ls {HOME}/yolov9/runs/train/exp/
# Out:
# confusion_matrix.png				     P_curve.png       train_batch2.jpg
# events.out.tfevents.1714549377.8b75aaa2d84b.12894.0  PR_curve.png      val_batch0_labels.jpg
# F1_curve.png					     R_curve.png       val_batch0_pred.jpg
# hyp.yaml					     results.csv       val_batch1_labels.jpg
# labels_correlogram.jpg				     results.png       val_batch1_pred.jpg
# labels.jpg					     train_batch0.jpg  weights
# opt.yaml					     train_batch1.jpg

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/results.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/confusion_matrix.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/F1_curve.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/labels_correlogram.jpg", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/PR_curve.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/P_curve.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/R_curve.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/labels.jpg", width=1000)

# %%
# %cd {HOME}/yolov9

# !python val.py \
--img 640 --batch 32 --conf 0.001 --iou 0.7 --device 0 \
--data {dataset.location}/data.yaml \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt
# Out:
# /content/yolov9/yolov9
# val: data=/content/yolov9/yolov9/project1-2/data.yaml, weights=['/content/yolov9/yolov9/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25419441 parameters, 0 gradients, 102.5 GFLOPs
# val: Scanning /content/yolov9/yolov9/project1-2/valid/labels.cache... 40 images, 0 backgrounds, 0 corrupt: 100% 40/40 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:05<00:00,  2.88s/it]
#                    all         40        767      0.753      0.291      0.323      0.188
#                bicycle         40         10      0.438        0.5      0.366      0.101
#                    bus         40         13      0.861      0.462      0.599      0.502
#                    car         40        377      0.816      0.658      0.747      0.493
#             motorcycle         40          2          1          0          0          0
#          other vehicle         40          2          1          0     0.0169     0.0152
#             pedestrian         40         80      0.666       0.35      0.435      0.189
#                  rider         40          3          1          0          0          0
#          traffic light         40         96      0.585      0.365      0.379      0.178
#           traffic sign         40        158      0.552       0.31      0.376      0.166
#                  truck         40         26      0.617      0.269      0.309      0.239
# Speed: 1.9ms pre-process, 96.9ms inference, 19.5ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp

# %%
# !python detect.py \
--img 1280 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt \
--source {dataset.location}/test/images
# Out:
# detect: weights=['/content/yolov9/yolov9/runs/train/exp/weights/best.pt'], source=/content/yolov9/yolov9/project1-2/test/images, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25419441 parameters, 0 gradients, 102.5 GFLOPs
# image 1/14 /content/yolov9/yolov9/project1-2/test/images/00699de6-58847872_jpg.rf.9330dee0787982b4e3288aa57a38f060.jpg: 1280x1280 1 bus, 14 cars, 15 pedestrians, 5 traffic lights, 17 traffic signs, 1 truck, 17.3ms
# image 2/14 /content/yolov9/yolov9/project1-2/test/images/01c9d396-c1de70b1_jpg.rf.32fea6f23f9d8385098434a4c046d6e1.jpg: 1280x1280 1 bus, 10 cars, 1 traffic light, 18 traffic signs, 2 trucks, 17.4ms
# image 3/14 /content/yolov9/yolov9/project1-2/test/images/01cde341-bde786dc_jpg.rf.d21dc726a12c3e3eb2b4de61f18c7a66.jpg: 1280x1280 30 cars, 1 pedestrian, 4 traffic lights, 4 traffic signs, 17.2ms
# image 4/14 /content/yolov9/yolov9/project1-2/test/images/021df36f-9dc059b8_jpg.rf.1a883e277421fa58397695ae0594205f.jpg: 1280x1280 21 cars, 3 traffic lights, 11 traffic signs, 17.2ms
# image 5/14 /content/yolov9/yolov9/project1-2/test/images/0224ccfa-4551648a_jpg.rf.244816d204ebca3ab313053e5febf700.jpg: 1280x1280 13 cars, 1 traffic light, 5 traffic signs, 1 truck, 17.2ms
# image 6/14 /content/yolov9/yolov9/project1-2/test/images/02ee373a-44f142e5_jpg.rf.8daaf94cb1e4c7f5d9c0d70a489a1bc4.jpg: 1280x1280 6 cars, 1 pedestrian, 2 traffic signs, 19.1ms
# image 7/14 /content/yolov9/yolov9/project1-2/test/images/031675b4-8c9d08cb_jpg.rf.62734e86b41d38b3b6e6868297da4474.jpg: 1280x1280 13 cars, 9 pedestrians, 2 traffic lights, 6 traffic signs, 17.2ms
# image 8/14 /content/yolov9/yolov9/project1-2/test/images/034d18b7-c6a28282_jpg.rf.b46d291d241a0d6d73645064d0d08b73.jpg: 1280x1280 23 cars, 1 truck, 17.2ms
# image 9/14 /content/yolov9/yolov9/project1-2/test/images/04089f1c-d41e13f0_jpg.rf.3a57a9fe32b30d6c647c89284316018c.jpg: 1280x1280 1 bicycle, 16 cars, 4 pedestrians, 22 traffic lights, 21 traffic signs, 17.2ms
# image 10/14 /content/yolov9/yolov9/project1-2/test/images/04200e90-4a4c631e_jpg.rf.c57cf7e57bb6a4b209ae3e11d73f3a3d.jpg: 1280x1280 13 cars, 1 pedestrian, 2 traffic lights, 11 traffic signs, 2 trucks, 17.2ms
# image 11/14 /content/yolov9/yolov9/project1-2/test/images/0458c2b9-7ebcef58_jpg.rf.a8683682e824aaf0d1b532f5b39d6db4.jpg: 1280x1280 12 cars, 2 pedestrians, 2 traffic lights, 8 traffic signs, 1 truck, 17.2ms
# image 12/14 /content/yolov9/yolov9/project1-2/test/images/051b9909-499aaeb3_jpg.rf.e284519841be7493f8de566d85b39bbd.jpg: 1280x1280 10 cars, 18.9ms
# image 13/14 /content/yolov9/yolov9/project1-2/test/images/072a5b71-dfd14a9a_jpg.rf.30b231596d5a0ce6678634ab0afaa5b7.jpg: 1280x1280 1 bicycle, 2 buss, 15 cars, 10 pedestrians, 3 traffic lights, 21 traffic signs, 2 trucks, 18.1ms
# image 14/14 /content/yolov9/yolov9/project1-2/test/images/07398e6d-65825072_jpg.rf.808594db74332ac7885ef141b3ff6b64.jpg: 1280x1280 17 cars, 5 pedestrians, 19 traffic lights, 32 traffic signs, 17.9ms
# Speed: 1.5ms pre-process, 17.6ms inference, 41.5ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp

# %%
import glob

from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp/*.jpg')[:2]:
      display(Image(filename=image_path, width=600))

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/results.png", width=1000)

# %%
# !pip install -q inference supervision

# %%
import cv2
import random
import getpass

import supervision as sv

from inference import get_model

# %matplotlib inline

# %%
version.deploy(model_type="yolov9", model_path=f"{HOME}/yolov9/runs/train/exp")
# Out:
# View the status of your deployment at: https://app.roboflow.com/uday-uejhk/project1-agenr/2
# Share your model with the world at: https://universe.roboflow.com/uday-uejhk/project1-agenr/model/2
